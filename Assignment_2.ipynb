# %% [markdown]
# <a href="https://colab.research.google.com/github/sambhav3009/UCS420/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
r = 1024170305
L = [int(x) * 10 for x in str(r)]
print("1. L =",L)

#2
L.append(80)
print("2. After append:",L)
#3
L.insert(2, 65)
print("3. After insert:", L)

#4
L.remove(70)
print("4. After remove:", L)

L.pop(1)
print("4. After pop:", L)

#5
L.sort()
print("5. Ascending:", L)

L.sort(reverse=True)
print("5. Descending:",L)

#6
print("6. First 3:",L[:3])
print("6. Last 3:", L[-3:])

#7
a=sum(L) /len(L)
N=[x for x in L if x > a]

print("7. Average:", a)
print("Elements greater than average:", N)
# Out:
# 1. L = [10, 0, 20, 40, 10, 70, 0, 30, 0, 50]
# 2. After append: [10, 0, 20, 40, 10, 70, 0, 30, 0, 50, 80]
# 3. After insert: [10, 0, 65, 20, 40, 10, 70, 0, 30, 0, 50, 80]
# 4. After remove: [10, 0, 65, 20, 40, 10, 0, 30, 0, 50, 80]
# 4. After pop: [10, 65, 20, 40, 10, 0, 30, 0, 50, 80]
# 5. Ascending: [0, 0, 10, 10, 20, 30, 40, 50, 65, 80]
# 5. Descending: [80, 65, 50, 40, 30, 20, 10, 10, 0, 0]
# 6. First 3: [80, 65, 50]
# 6. Last 3: [10, 0, 0]
# 7. Average: 30.5
# Elements greater than average: [80, 65, 50, 40]

# %%
scores = tuple(L[:8])

#1
h = max(scores)
hi = scores.index(h)
l = min(scores)
lc = scores.count(l)

print("Highest:", h, "Index:", hi)
print("Lowest:", l, "Count:", lc)

#2
r=list(scores[::-1])
print("Reversed list:", r)

#3
x=int(input("Enter a score: "))

if x in scores:
    print("First occurrence index:", scores.index(x))
else:
    print("Score not present")

#4
#scores[0]=100

#5
f, s, *rem = scores
print("First:", f)
print("Second:", s)
print("Remaining:", rem)
# Out:
# Highest: 80 Index: 0
# Lowest: 10 Count: 2
# Reversed list: [10, 10, 20, 30, 40, 50, 65, 80]
# Enter a score: 65
# First occurrence index: 1
# First: 80
# Second: 65
# Remaining: [50, 40, 30, 20, 10, 10]

# %%
import random

#1
random.seed(1024170305)
L = [random.randint(100, 900) for _ in range(100)]
print("1. Random numbers:", L)

#2
o=[x for x in L if x%2 != 0]
print("2. Odd count:", len(o))
print("Odd numbers:", o)

#3
e=[x for x in L if x%2 ==0]
print("3. Even count:", len(e))
print("Even numbers:", e)

#4
def prime(x):
    if x < 2:
        return False
    for i in range(2, int(x ** 0.5)+1):
        if x % i == 0:
            return False
    return True

p = [x for x in L if prime(x)]
print("4. Prime count:", len(p))
print("Prime numbers:", p)

#5
m = max(L, key=L.count)
print("5. Most frequent:", m)
print("Frequency:", L.count(m))
# Out:
# 1. Random numbers: [136, 475, 872, 897, 855, 530, 505, 717, 867, 533, 620, 152, 133, 397, 702, 811, 164, 759, 842, 339, 639, 837, 755, 167, 220, 714, 181, 527, 585, 152, 112, 845, 453, 206, 856, 357, 748, 891, 438, 446, 571, 144, 207, 872, 866, 316, 431, 224, 809, 842, 393, 464, 772, 586, 374, 723, 426, 729, 790, 531, 511, 297, 228, 238, 770, 183, 743, 363, 182, 889, 644, 638, 185, 851, 416, 531, 874, 291, 711, 711, 414, 879, 739, 571, 446, 562, 660, 582, 175, 312, 224, 388, 822, 491, 548, 133, 547, 795, 207, 359]
# 2. Odd count: 53
# Odd numbers: [475, 897, 855, 505, 717, 867, 533, 133, 397, 811, 759, 339, 639, 837, 755, 167, 181, 527, 585, 845, 453, 357, 891, 571, 207, 431, 809, 393, 723, 729, 531, 511, 297, 183, 743, 363, 889, 185, 851, 531, 291, 711, 711, 879, 739, 571, 175, 491, 133, 547, 795, 207, 359]
# 3. Even count: 47
# ...

# %%
d= [1,0,2,4,1,7,0,3]

A= {x*7 for x in d}
B={x *9 for x in d}

print("A:", A)
print("B:", B)

#6
u=A.union(B)
print("Union:", u)

#7
i=A.intersection(B)
print("Intersection:", i)

#8
ab=A.difference(B)
ba=B.difference(A)

print("A - B:", ab)
print("B - A:", ba)


#9
s=A.symmetric_difference(B)
print("Symmetric difference:", s)

#10
print("A subset of B:", A.issubset(B))
print("B superset of A:", B.issuperset(A))

#11
x=int(input("Enter X: "))
A.discard(x)

print("A after discard:", A)

# discard() is safer because it does not give an error if X is absent.
# Out:
# A: {0, 7, 14, 49, 21, 28}
# B: {0, 36, 9, 18, 27, 63}
# Union: {0, 36, 7, 9, 14, 49, 18, 21, 27, 28, 63}
# Intersection: {0}
# A - B: {7, 14, 49, 21, 28}
# B - A: {36, 9, 18, 27, 63}
# Symmetric difference: {7, 9, 14, 18, 21, 27, 28, 36, 49, 63}
# A subset of B: False
# B superset of A: False
# Enter X: 65
# A after discard: {0, 7, 14, 49, 21, 28}

# %%
my_dict = {
    "name": "Sambhav Jain",
    "roll_no": "1024170305",
    "branch": "CS",
    "age": 19,
    "city": "Patiala"
}

#1
my_dict["location"] = my_dict.pop("city")
print("1", my_dict)

#2
my_dict["cgpa"] = 9.42
print("2", my_dict)

#3
my_dict["age"] += 1
print("3", my_dict)

#4
d1 = my_dict.copy()
d2 = my_dict.copy()

d1.pop("branch")
del d2["branch"]

print("pop:", d1)
print("del:", d2)

# pop() returns the removed value, while del only removes the key-value pair.

# v
for k, v in my_dict.items():
    print(k, "→", v)

# vi
if "email" in my_dict:
    print(my_dict["email"])
else:
    print("Email not present")

# vii
friend_dict = {
    "name": "Rohan",
    "roll_no": "1024170306",
    "branch": "CS",
    "age": 20,
    "city": "Delhi"
}

d = {**my_dict, **friend_dict}
print( d)


# viii
d = {k: v for k, v in my_dict.items() if isinstance(v, str)}
print(d)
# Out:
# 1 {'name': 'Sambhav Jain', 'roll_no': '1024170305', 'branch': 'CS', 'age': 19, 'location': 'Patiala'}
# 2 {'name': 'Sambhav Jain', 'roll_no': '1024170305', 'branch': 'CS', 'age': 19, 'location': 'Patiala', 'cgpa': 9.42}
# 3 {'name': 'Sambhav Jain', 'roll_no': '1024170305', 'branch': 'CS', 'age': 20, 'location': 'Patiala', 'cgpa': 9.42}
# pop: {'name': 'Sambhav Jain', 'roll_no': '1024170305', 'age': 20, 'location': 'Patiala', 'cgpa': 9.42}
# del: {'name': 'Sambhav Jain', 'roll_no': '1024170305', 'age': 20, 'location': 'Patiala', 'cgpa': 9.42}
# name → Sambhav Jain
# roll_no → 1024170305
# branch → CS
# age → 20
# location → Patiala
# cgpa → 9.42
# Email not present
# {'name': 'Rohan', 'roll_no': '1024170306', 'branch': 'CS', 'age': 20, 'location': 'Patiala', 'cgpa': 9.42, 'city': 'Delhi'}
# {'name': 'Sambhav Jain', 'roll_no': '1024170305', 'branch': 'CS', 'location': 'Patiala'}
